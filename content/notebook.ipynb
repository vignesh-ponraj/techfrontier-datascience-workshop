# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# TASK 1 — Load your team's dataset
#
# Each team has been assigned a different file named like
# 'secret_dataset_3.csv'. Look in the file browser on the left and
# find the one assigned to your team.
#
# Your job:
#   - Use pandas to read that CSV file.
#   - Assign the result to a variable called `df` so the rest of the
#     notebook can use it.
#
# Check the cheatsheet under "Loading data" for the function you need.

# %%
# Display the first 5 rows to see the columns and data types
# Hint: Use the .head() method

df.head()

# %%
# Check for missing values in each column

print("Missing values per column:")
print(df.isnull().sum())

# TASK: If you have missing values, decide how to handle them. 
# You can fill them with the median or drop them.
# Example: df = df.fillna(0) or df = df.dropna()

# Write your cleaning code below:

# %%
# Generate descriptive statistics (mean, median, std dev, etc.)
# Hint: Use the .describe() method

stats = df.describe()

print("--- Statistical Fingerprint ---")
print(stats)

# CHALLENGE: Look at the 'mean' and 'max'. 
# Are the numbers in the hundreds? Thousands? Decimals? 
# What does the 'std' (standard deviation) tell you about the consistency of the data?

# %%
# TASK: Sort your data to find the 'Top 5' highest values in a column.
# Replace 'COLUMN_NAME' with one of the headers you saw in Step 1.
sorted_data = df.sort_values(by='COLUMN_NAME', ascending=False)

print("Top 5 Entries:")
print(sorted_data.head())

# TASK: Filter the data. 
# Try to find rows where a specific value is greater than the average.
# high_value_rows = df[df['COLUMN_NAME'] > df['COLUMN_NAME'].mean()]

# %%
# We want to see the relationship between two columns.
plt.figure(figsize=(10, 6))

# Choose your X and Y axes carefully based on your dataset headers.
# Use sns.barplot, sns.lineplot, or sns.scatterplot
sns.barplot(data=df.head(15), x='X_COLUMN', y='Y_COLUMN', palette='magma')

plt.title("Team Investigation: Preliminary Analysis")
plt.xticks(rotation=45)
plt.show()

# %%
### Team Detective Report
1. **The Topic:** We believe this dataset is about ________________.
2. **Evidence A (Stats):** We noticed the average value was _______ which suggests _______.
3. **Evidence B (Visual):** The chart shows a clear trend between _______ and _______.
4. **Conclusion:** (e.g., "This is definitely 2024 weather data for El Paso because...")
